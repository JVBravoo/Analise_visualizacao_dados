# %% [markdown]
# <a href="https://colab.research.google.com/github/JVBravoo/Analise_visualizacao_dados/blob/master/Analise_Exploratoria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Very [util](https://www.datasciencemadesimple.com/r-scatter-plot/)

# %%
library(ggplot2)

# %%
df <- read.csv("netflix_titles.csv", stringsAsFactors=FALSE)

# %%
head(df)
# Out:
#   show_id  type    title
# 1 81145628 Movie   Norm of the North: King Sized Adventure
# 2 80117401 Movie   Jandino: Whatever it Takes
# 3 70234439 TV Show Transformers Prime
# 4 80058654 TV Show Transformers: Robots in Disguise
# 5 80125979 Movie   #realityhigh
# 6 80163890 TV Show Apaches
#   director
# 1 Richard Finn, Tim Maltby
# 2
# 3
# 4
# 5 Fernando Lebrija
# 6
#   cast
# 1 Alan Marriott, Andrew Toth, Brian Dobson, Cole Howard, Jennifer Cameron, Jonathan Holmes, Lee Tockar, Lisa Durupt, Maya Kay, Michael Dobson
# 2 Jandino Asporaat
# 3 Peter Cullen, Sumalee Montano, Frank Welker, Jeffrey Combs, Kevin Michael Richardson, Tania Gunadi, Josh Keaton, Steve Blum, Andy Pessoa, Ernie Hudson, Daran Norris, Will Friedle
# 4 Will Friedle, Darren Criss, Constance Zimmer, Khary Payton, Mitchell Whitfield, Stuart Allan, Ted McGinley, Peter Cullen
# ...

# %%
str(df)
# Out:
# 'data.frame':	6234 obs. of  12 variables:
#  $ show_id     : int  81145628 80117401 70234439 80058654 80125979 80163890 70304989 80164077 80117902 70304990 ...
#  $ type        : Factor w/ 2 levels "Movie","TV Show": 1 1 2 2 1 2 1 1 2 1 ...
#  $ title       : Factor w/ 6172 levels "¡Ay, mi madre!",..: 3590 2452 5703 5707 4 405 466 1639 1702 1948 ...
#  $ director    : Factor w/ 3302 levels "","A. L. Vijay",..: 2548 1 1 1 943 1 983 2626 1 1140 ...
#  $ cast        : Factor w/ 5470 levels "","4Minute, B1A4, BtoB, ELSIE, EXID, EXO, Got7, INFINITE, KARA, Shinee, Sistar, VIXX, Nine Muses, BTS, Secret, Topp Dogg",..: 200 2168 3997 5323 3757 206 488 1585 1 2135 ...
#  $ country     : Factor w/ 555 levels "","Argentina",..: 500 381 445 445 445 336 50 78 445 540 ...
#  $ date_added  : Factor w/ 1525 levels ""," April 1, 2014",..: 1525 1524 1523 1523 1522 1522 1522 1522 1522 1522 ...
#  $ release_year: int  2019 2016 2013 2016 2017 2016 2014 2017 2017 2014 ...
# ...

# %% [markdown]
# Há quatro tipos básicos de dados no R:
#
# *Numeric*: dados numéricos contínuos;
#
# *Integer*: dados numéricos inteiros;
#
# *Factor*: dados categóricos (nominais) divididos em níveis;
#
# *Character*: dados nominais não explicitamente divididos em categorias;
#
# *Logical*: dados lógicos TRUE/FALSE equivalentes a 1/0.

# %%
# Pega os valores de uma determinada coluna

table(df$rating)
# Out:
#                 G    NC-17       NR       PG    PG-13        R    TV-14
#       10       37        2      218      184      286      508     1698
#     TV-G    TV-MA    TV-PG     TV-Y    TV-Y7 TV-Y7-FV       UR
#      149     2027      701      143      169       95        7

# %%
boxplot(release_year ~ rating, data=df, main = "Release year", las=2)
# Out:
# Plot with title “Release year”

# %%
# Simple Bar Plot for the Years that the movies were released
counts <- table(df$release_year)
barplot(counts, main="Release Year")
# Out:
# Plot with title “Release Year”

# %%
count <- table(df$rating)
barplot(count, horiz=TRUE, main="Rating Distribution", las=2, col=rainbow(15))
# Out:
# Plot with title “Rating Distribution”

# %%
# d <- ggplot(df, aes(x=type, y=rating)) + geom_hex
# fig <- ggplotly(d)
# fig

# %%
barplot(table(df1$type), col = rainbow(2))
# Out:
# plot without title

# %%
x <- table(df$type)
pct <- round(x/sum(x)*100)
labels <- paste(paste(unique(df$type), pct), "%", sep = " ")
pie(x, labels = labels,col = rainbow(2))
# Out:
# plot without title

# %% [markdown]
# ## Filmes do Brasil

# %%
df1 <- dplyr::filter(df, grepl("Brazil", country))

# %%
head(df1)
# Out:
#   show_id  type    title                     director
# 1 81011955 Movie   Paradise Lost             Monique Gardenberg
# 2 80214464 Movie   Rafinha Bastos: Ultimatum
# 3 81137484 Movie   Elena                     Petra Costa
# 4 81137482 Movie   Olmo & the Seagull        Petra Costa, Lea Glob
# 5 80221210 TV Show Brotherhood
# 6 81003880 TV Show Blood Pact
#   cast
# 1 Júlio Andrade, Lee Taylor, Hermila Guedes, Julia Konrad, Erasmo Carlos, Marjorie Estiano, Seu Jorge, Jaloo, Felipe Abib, Humberto Carrão, Malu Galli
# 2 Rafinha Bastos
# 3
# 4 Olivia Corsini, Sergio Nicolai, Arman Saribekyan, Sylvain Jailloux, Francis Ressort, Pancho Garcia Aguirre, Shaghayegh Beheshti, Elena Bellei, Sébastien Brottet-Michel, Célia Catalifo
# 5 Naruna Costa, Seu Jorge, Hermila Guedes, Lee Taylor, Danilo Grangheia, Wesley Guimarães, Pedro Wagner
# 6 Guilherme Fontes, Ravel Cabral, Jonathan Haagensen, André Ramiro, Adriano Garib, Mel Lisboa, Cristina Lago
# ...

# %%
pie(table(df1$release_year), col=rainbow(10))
# Out:
# plot without title

# %%
barplot(table(df1$type), col = rainbow(2))
# Out:
# plot without title

# %%
x <- table(df1$type)
pct <- round(x/sum(x)*100)
labels <- paste(paste(unique(df1$type), pct), "%", sep = " ")
pie(x, labels = labels,col = rainbow(2))
# Out:
# plot without title
